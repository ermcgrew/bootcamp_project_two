# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
import sqlite3
import pandas as pd

# %%
engine = create_engine("sqlite:///database.sqlite", echo=False)

# %%
session = Session(engine)

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['artists', 'content', 'genres', 'labels', 'reviews', 'years']

# %%
session.query()

# %%
con = sqlite3.connect("/Users/joescuteri/Desktop/Personal Bootcamp/PersonalHW/13-Project-2/database.sqlite")

# %%
artists_df = pd.read_sql('SELECT * FROM artists', con)
content_df = pd.read_sql('SELECT * FROM content', con)
genres_df = pd.read_sql('SELECT * FROM genres', con)
labels_df = pd.read_sql('SELECT * FROM labels', con)
reviews_df = pd.read_sql('SELECT * FROM reviews', con)
years_df = pd.read_sql('SELECT * FROM years', con)

# %%
reviews_df
# Out:
#        reviewid                        title            artist  \
# 0         22703                    mezzanine    massive attack
# 1         22721                 prelapsarian          krallice
# 2         22659         all of them naturals      uranium club
# 3         22661                  first songs  kleenex, liliput
# 4         22725                    new start              taso
# ...         ...                          ...               ...
# 18388      1535               let us replay!           coldcut
# 18389      1341                         1999           cassius
# 18390      5376                  out of tune          mojave 3
# 18391      2413  singles breaking up, vol. 1     don caballero
# 18392      3723    left for dead in malaysia    neil hamburger
#
#                                                      url  score  \
# 0      http://pitchfork.com/reviews/albums/22703-mezz...    9.3
# 1      http://pitchfork.com/reviews/albums/22721-prel...    7.9
# ...
